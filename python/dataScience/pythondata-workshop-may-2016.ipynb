# %% [markdown]
# # Data-mining and Introduction to Machine Learning using Python
# ***

# %% [markdown]
# ##### Why and what is [IPython notebook](https://ipython.org/notebook.html)? easy to explore from the notebook and easy to share and visualize. Can be used with R, Julia, Python

# %% [markdown]
# Data-mining, data-crunching, data-munging, data-wrangling.
#
# It all involves certain activities like data cleaning, data transformation, data preparation, data visualization.
#
# But it all starts with getting ***RAW DATA***

# %% [markdown]
# # Getting raw data

# %% [markdown]
# #### To first to some validating and analysis of data, we need to get the raw data

# %% [markdown]
# ### A http request

# %%
import requests

print(requests.get("http://www.blocket.se/stockholm?q=macbook air").text)
# Out:
# <!doctype html>
# <html lang="sv">
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta name="viewport" content="width=1012" />
#
#
#
# <title>Stockholm  | Blocket</title>
# <meta name="keywords" content=",Stockholm" />
#
# <meta name="description" content="On Blocket you can see  ads in Stockholm" />
#
#
#
#
# 		<link rel="canonical" href="http://www.blocket.se/stockholm/">
#
#
#
#
#
#
# 		<link rel="next" href="http://www.blocket.se/hela_sverige?q=macbook+air&o=2" />
#
#
#
#
# <meta name="googlebot" content="noarchive" />
# <meta name="application-name" content="Blocket"/>
#
#
#
#
#
#
#
# <meta name="google" content="nositelinkssearchbox">
#
#
# <link rel="shortcut icon" href="/favicon.ico" type="image/x-icon">
# <link rel="apple-touch-icon" href="/apple-touch-icon.png">
# <link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png">
# <link rel="apple-touch-icon" sizes="72x72" href="/apple-touch-icon-72x72.png">
# <link rel="apple-touch-icon" sizes="76x76" href="/apple-touch-icon-76x76.png">
# <link rel="apple-touch-icon" sizes="114x114" href="/apple-touch-icon-114x114.png">
# <link rel="apple-touch-icon" sizes="120x120" href="/apple-touch-icon-120x120.png">
# <link rel="apple-touch-icon" sizes="144x144" href="/apple-touch-icon-144x144.png">
# <link rel="apple-touch-icon" sizes="152x152" href="/apple-touch-icon-152x152.png">
# <link rel="image_src" href="/apple-touch-icon-152x152.png">
# <meta name="msapplication-TileColor" content="#f8edcd">
# <meta name="msapplication-TileImage" content="/apple-touch-icon-152x152.png">
#
#
#
# <link href="/css/873f1fed27f707d5d4b9780670f9e60f/sprite_list.css" rel="stylesheet" type="text/css" />
#
#
#
#
#
#
# <link href="/css/97c84e89d68101e42d423c484d25d6fc/blocket_list.css" rel="stylesheet" type="text/css" />
#
#
#
#
#
#
# <link href="/css/927db19229c56dfdd9eec3f3f7ba4003/sprite_common.css" rel="stylesheet" type="text/css" />
#
#
#
#
#
#
#
# <link href="/css/f9b8e62f98a72fd21e5beec6db30d4ff/sprite_blocket_maps.css" rel="stylesheet" type="text/css" />
#
#
#
#
#
#
#
# <link href="/css/f4d281ddc95a4285bdd21b5a0a5cf366/sprite_campaigns.css" rel="stylesheet" type="text/css" />
#
#
#
#
#
#
# <link href="/css/f1c36cf880289818dfac4a3f65de5699/campaigns.css" rel="stylesheet" type="text/css" />
#
#
#
#
#
# <link href="/css/515b13255840d55a0ce8bbceb1e02c33/blocket_common_bootstraped.css" rel="stylesheet" type="text/css" />
#
#
#
#
#
# <link href="/css/94677/blocket-ui.min.css" rel="stylesheet" type="text/css" />
#
#
#
#
#
#
#
#
#
#
#
# <script src="/js/643c1fcd76332135f423623bc61b510f/jquery-1.9.1.min.js" type="text/javascript"></script>
#
# <script src="/js/94677/blocket-ui.min.js" type="text/javascript"></script>
#
# <script src="/js/daf322de471536a5c9d293e94e485606/common.js" type="text/javascript"></script>
#
#
# <!--[if lt IE 9]>
# <script src="/js/5a98a86b5cb48c1506f338463259ce41/html5shiv.js"></script>
# <![endif]-->
#
# <script type="text/javascript">
# // Handle postMessage
# blocket("@bconf").extend({
# postmessage: {
# allowed_origin: {
#  power_format: [
#  "http://www.blocket.nu",
#  "https://www.blocket.nu",
#  "http://www.blocket.com",
#  "https://www.blocket.com",
#  "http://www.blocket.se",
#  "https://www.blocket.se"
#
# ],
#  resize_iframe: [
#  "https://www.blocket.com",
#  "http://www.blocket.com",
#  "https://jobb.blocket.se",
#  "http://jobb.blocket.se",
#  "https://www.blocket.se",
#  "http://www.blocket.se"
#
# ],
#  show_hide_iframe: [
#  "https://www.blocket.nu",
#  "http://www.blocket.nu",
#  "https://jobb.blocket.se",
#  "http://jobb.blocket.se",
#  "https://www.blocket.se",
#  "http://www.blocket.se",
#  "https://www.blocket.com",
#  "http://www.blocket.com"
#
# ]
#
# }
# }
# });
# if (window.addEventListener) {
# window.addEventListener("message", handle_message, false);
# } else if (window.attachEvent) {
# window.attachEvent("onmessage", handle_message);
# }
# function handle_message(event) {
# var data = JSON.parse(event.data);
# try {
# if ($.inArray(event.origin, blocket.bconf.postmessage.allowed_origin[data.func]) > -1) {
# if (document.querySelector(data.target).contentWindow === event.source) {
# blocket.apps.common.postmessage[data.func](data, event);
# }
# }
#
# } catch (e) {
# if (e instanceof TypeError !== true) {
# throw e;
# }
# }
# }
# blocket("@bconf").extend({
# postmessage: {
# base_url: {
# http: "http://www.blocket.com",
# https: "https://www.blocket.com"
# }
# }
# });
# </script>
#
#
#
#
#
#
#
# </head>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <body id="li" data-application-name="list_ads" class="    ">
# <noscript>
# <iframe src="http://www.blocket.se/nojs.htm" style="height: 0; width: 0"></iframe>
# </noscript>
#
#
#
#
# <div class="handheld_tip">Mobilsurfare - gå hit istället! <a href="http://mobil.blocket.se">http://mobil.blocket.se</a></div>
#
#
#
#
#
#
#
#
#  <header id="header_navbar" class="navbar navbar-static-top navbar-default"> <div class="container nopadding"> <div id="blocket_header" class="navbar-header">  <a id="blocket_logo" class="navbar-brand npl" href="http://www.blocket.se" onclick="return xt_click(this,'C','','Navigering::Topp::Blocket logo','N');" > <img src="https://www.blocket.com/img/transparent.gif" class="sprite_common_blocket_logo_flat_small header_logo" alt="Blocket" title="Blocket">
#  </a> </div> <nav role="navigation"> <ul id="top_nav" class="nav navbar-nav font-large">   <li class="selected"> <a rel="nofollow" onclick="return xt_click(this, 'C', '', 'Navigering::Topp::Alla annonser', 'N');" href="http://www.blocket.se/stockholm?ca=11" > Alla annonser </a> </li>  <li class=""> <a onclick="return xt_click(this, 'C', '', 'Navigering::Topp::Jobb', 'N');" href="https://jobb.blocket.se/?ca=11&amp;w=1" > Jobb </a> </li> <li class=""> <a onclick="return xt_click(this, 'C', '', 'Navigering::Topp::Bostad', 'N');" href="http://www.blocket.se/bostad/?ca=11&amp;w=1" > Bostad </a> </li>  </ul> <ul class="nav navbar-nav navbar-right navbar-notification">   <li id="top_nav_support" class="secondary_navitem" > <a href="https://blocket.zendesk.com" onclick="return xt_click(this, 'C', '', 'Navigering::Topp::Kundservice', 'N');" > Kundservice </a> </li>   <li class="secondary_navitem float_right">
#     <a type="button" role="button" class="btn btn-link pam" data-container="body" data-js="preonboarding-popover" data-toggle="popover" tabindex="1" data-placement="bottom" data-html="true" data-trigger="focus">
#         <i class="blocket-icon blocket-icon-chat font-large"></i>
#
#     </a>
#      <div id="preonboarding-popover-content" style="display: none">
#      <button type="button" class="close" data-dismiss="alert"><span>×</span></button>
#         <div class="row mts">
#             <div class="col-md-8">
#                 <h6 class="mts"><strong><span class="text-danger">Psst!</span> Snart lanserar vi ett nytt sätt att skicka meddelanden på Blocket</strong></h6>
#             </div>
#             <div class="col-md-4">
#                 <div class="sprite_common_icon_blue_notification pull-right mrs"></div>
#             </div>
#         </div>
#         <div class="row">
#             <div class="col-md-10">
#                 <p>
#                     För att underlätta för dig som köper och säljer på Blocket får du snart en samlad översikt över dina köp- och säljmeddelanden.
#
#
#
#
#                             <a href="https://login.schibsted.com/flow/login?client_id=54fdbd1aa24e7b191d360df8&response_type=code&locale=sv_SE&state=8c161c84d68744f2c7ea62fe9d75f1f17f2d5771&redirect_uri=https%3A%2F%2Fwww.blocket.se%2Fspid%2Freturn" onclick="return xt_click(this,'C','','Navigering::Topp::Preboarding::Login','N')"><strong>Logga in redan idag.</strong></a>
#
#
#                 </p>
#             </div>
#             <div class="col-xs-6 col-xs-offset-3 pas">
#                 <button class="btn btn-secondary pull-left" data-dismiss="alert">Stäng</button>
#                 <a href="https://blocket.zendesk.com/hc/sv/articles/207819415-Skicka-meddelanden" class="btn btn-primary pull-right">Läs mer</a>
#             </div>
#         </div>
#      </div>
# </li>
#    <li id="top_nav_mypages" class="secondary_navitem " >         <a onclick="return xt_click(this, 'C', '', 'Navigering::Topp::Mina sidor', 'N');" class="nav_link_mypages npr" href="https://www.blocket.se/konto/senaste_sidan" > <span class="blocket-icon blocket-icon-avatar"></span><span class="prxs plxs">Logga in</span><span id="spid_logo_navbar"><img class="sprite_common_spid_logo_small_grey" src="/img/transparent.gif"></span>
#  </a>    </li>  </ul>   <a id="top_nav_ai" class="btn btn-sm btn-primary mts mrm pull-right" onclick="return xt_click(this, 'C', '', 'Navigering::Topp::Lagg in annons', 'N');"  href="https://www.blocket.se/ai?ca=11"   > Lägg in annons </a>    </nav> </div></header>
#
# <section
# id="blocket"
# data-js="blocket_container"
# class="container col-main"
# >
#
# <div
# id="blocket_content"
# data-js="blocket_content"
# class="row"
# >
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div
# 	data-js="list_filter"
# 	class="list_filter_container
#
# 	cat_all
# 	type_s
# 	col-xs-12"
# >
#
#
#
#
#
#
#     <div id="panorama" data-js="panorama" data-panorama-type="bootstrap">
#
#
#
#
#
#
# <article data-js-placement="panorama_adtech" id="panorama_adtech" style="" class="fif"></article>
# 		<script>
# 			data = {
# 				id: "panorama_adtech",
# 				loadtype: "rsi_segs",
# 				lazyload: "0",
# 				params: "ADTECH;alias=blocketd_listning_li_panorama;loc=100;target=_blank;kvsearchword=macbook%20air;kvcounty=11",
# 				width: 980,
# 				height: 120,
# 				hash_override_enabled: 1,
# 				source: 0,
# 				bootstrap: 0
# 			};
# 			blocket.apps.common.placements.push(data);
# 		</script>
#
#
#
#
#     </div>
#
#
#
# <div class="row">
# 	<div class="list_top col-xs-12 ptm" role="search">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div id="search-wrapper" data-js="update_search" class="root_cat_">
# <div id="search" class="searchbox_standard ">
# <form id="search_form" data-js="search_form" action="http://www.blocket.se/stockholm?ca=11" method="get" role="form">
#
#
#
# <div class="row form-group">
# <div class="col-xs-12">
# <div id="search_field" class="input-group mrs pull-left">
# <input id="searchtext" data-ajax-update="false" name="q" class="search_query form-control" value="macbook air" placeholder="Sök..." tabindex="1" />
# <input name="sort" type="hidden" value="" />
# <div class="input-group-btn">
# <div class="btn-group rich_dropdown">
# <label id="category_dropdown" class="btn btn-default fixed-width" tabindex="-1">
# <span class="rich-dropdown-label" data-js="rich_dropdown_label">
#
# Alla kategorier
#
# </span>
# <select data-update-banners="true" id="catgroup" name="cg" class="search_category rich_dropdown" tabindex="2" role="menu" data-update-news="true">
#
#
# <option value="0" >Alla kategorier</option>
# <option value="3000" data-url="http://www.blocket.se/bostad?ca=11&w=1">BOSTAD &rsaquo;</option>
# <option value="9000" data-url="https://jobb.blocket.se/index.html">JOBB &rsaquo;</option>
#
# <option class="blind" value="no_use" disabled="disabled"></option>
#
# <option class="main_category" value="1000" >FORDON</option>
#
#
# <option class="mls" value="1020" >Bilar</option>
#
# <option class="mls" value="1040" >Bildelar &amp; Biltillbehör</option>
#
# <option class="mls" value="1060" >Båtar</option>
#
# <option class="mls" value="1080" >Båtdelar &amp; tillbehör</option>
#
# <option class="mls" value="1100" >Husvagnar &amp; Husbilar</option>
#
# <option class="mls" value="1120" >Mopeder &amp; A-traktor</option>
#
# <option class="mls" value="1140" >Motorcyklar</option>
#
# <option class="mls" value="1160" >MC-delar &amp; tillbehör</option>
#
# <option class="mls" value="1220" >Lastbil, Truck &amp; Entreprenad</option>
#
# <option class="mls" value="1240" >Skogs- &amp; Lantbruksmaskiner</option>
#
# <option class="mls" value="1180" >Snöskotrar</option>
#
# <option class="mls" value="1200" >Snöskoterdelar &amp; tillbehör</option>
#
# <option class="blind" value="no_use" disabled="disabled"></option>
#
# <option class="main_category" value="2000" >FÖR HEMMET</option>
#
#
# <option class="mls" value="2020" >Bygg &amp; Trädgård</option>
#
# <option class="mls" value="2040" >Möbler &amp; Heminredning</option>
#
# <option class="mls" value="2060" >Husgeråd &amp; Vitvaror</option>
#
# <option class="mls" value="2026" >Verktyg</option>
#
# <option class="blind" value="no_use" disabled="disabled"></option>
#
# <option class="main_category" value="4000" >PERSONLIGT</option>
#
#
# <option class="mls" value="4080" >Kläder &amp; Skor</option>
#
# <option class="mls" value="4060" >Accessoarer &amp; Klockor</option>
#
# <option class="mls" value="4020" >Barnkläder &amp; Skor</option>
#
# <option class="mls" value="4040" >Barnartiklar &amp; Leksaker</option>
#
# <option class="blind" value="no_use" disabled="disabled"></option>
#
# <option class="main_category" value="5000" >ELEKTRONIK</option>
#
#
# <option class="mls" value="5020" >Datorer &amp; TV-spel</option>
#
# <option class="mls" value="5040" >Ljud &amp; Bild</option>
#
# <option class="mls" value="5060" >Telefoner &amp; Tillbehör</option>
#
# <option class="blind" value="no_use" disabled="disabled"></option>
#
# <option class="main_category" value="6000" >FRITID &amp; HOBBY</option>
#
#
# <option class="mls" value="6020" >Biljetter</option>
#
# <option class="mls" value="6024" >Resor</option>
#
# <option class="mls" value="6040" >Böcker &amp; Studentlitteratur</option>
#
# <option class="mls" value="6060" >Cyklar</option>
#
# <option class="mls" value="6080" >Djur</option>
#
# <option class="mls" value="6100" >Hobby &amp; Samlarprylar</option>
#
# <option class="mls" value="6120" >Hästar &amp; Ridsport</option>
#
# <option class="mls" value="6140" >Jakt &amp; Fiske</option>
#
# <option class="mls" value="6160" >Musikutrustning</option>
#
# <option class="mls" value="6180" >Sport &amp; Fritid</option>
#
# <option class="blind" value="no_use" disabled="disabled"></option>
#
# <option class="main_category" value="7000" >AFFÄRSVERKSAMHET</option>
#
#
# <option class="mls" value="7020" >Affärsöverlåtelser</option>
#
# <option class="mls" value="7040" >Inventarier &amp; Maskiner</option>
#
# <option class="mls" value="7060" >Lokaler &amp; Fastigheter</option>
#
# <option class="mls" value="7080" >Tjänster</option>
#
# <option class="blind" value="no_use" disabled="disabled"></option>
#
# <option class="main_category" value="8000" >--</option>
#
#
# <option class="mls" value="8020" >Efterlysningar</option>
#
# <option class="mls" value="8040" >Övrigt</option>
#
#
# </select>
# </label>
# </div>
# </div>
# </div>
#
#
#
#
#
# <div
# 	class="
# 		mrs
# 		pull-left
# 		">
#
# 	<div class="btn-group rich_dropdown ">
# 	    <label
# 			class="
# 				btn
# 				btn-default
# 				fixed-width
# 			"
# 			tabindex="-1"
# 			data-js="searcharea_region_dropdown">
# 	        <span class="rich-dropdown-label" data-js="rich_dropdown_label">
# 	            Stockholm
# 	        </span>
# 			<select data-js="searcharea_region" name="w" id="searcharea_simple" class="search_region search_where" onchange="blocket.apps.searchbox.SearchCrit(false, false, 'cat')" autocomplete="off"  tabindex="10">
# 	<option value="1" selected="selected">Stockholm</option>
#
# 	<option value="2" >Angränsande län</option>
# 	<option value="3" >Hela Sverige</option>
#
#
#
# </select>
#
# 	    </label>
# 	</div>
#
# 	<div class="btn-group rich_dropdown hide">
# 	    <label
# 			class="
# 				btn
# 				btn-default
# 				fixed-width
# 			"
# 			tabindex="-1"
# 			data-js="searcharea_region_dropdown">
# 	        <span class="rich-dropdown-label" data-js="rich_dropdown_label">
# 	            Stockholm
# 	        </span>
# 			<select  data-js="searcharea_region" name="w" onchange="blocket.apps.searchbox.on_search_expanded_change(this);" id="searcharea_expanded" class="search_region search_where rich_dropdown" autocomplete="off" style="display:none;" disabled="disabled" tabindex="10">
# 	<option value="1" selected="selected">Stockholm</option>
#
# 	<option value="2" >Angränsande län</option>
# 	<option value="3" >Hela Sverige</option>
# </select>
#
# 	    </label>
# 	</div>
#
# 	<div class="btn-group rich_dropdown hide">
# 	    <label
# 			class="
# 				btn
# 				btn-default
# 				fixed-width
# 			"
# 			tabindex="-1"
# 			data-js="searcharea_region_dropdown">
# 	        <span class="rich-dropdown-label" data-js="rich_dropdown_label">
# 	            Stockholm
# 	        </span>
# 			<select
# 	data-js="searcharea_region"
# 	name="w" id="searcharea_subarea"
# 	autocomplete="off"
# 	class="search_region search_where rich_dropdown"
# 	onchange="blocket.apps.searchbox.SearchCrit(false, false, 'cat')"
# 	style="display:none;" disabled="disabled"
# >
#
# 	<option value="1" selected="selected">Stockholm</option>
#
# 	<option value="2" >Angränsande län</option>
# 	<option value="3" >Hela Sverige</option>
#
#
#
# </select>
# 	    </label>
# 	</div>
#
# </div>
#
#
# <div data-js="area_selector" class="btn-group pull-left mrs" style="width: 185px;">
# 	<button data-js="area_selector_button" class="multiselect dropdown-toggle btn btn-default" data-toggle="dropdown" title="" type="button" data-ajax-update="false">
# 		<span class="pull-left multiselect-selected-text"><span data-js="area_selector_button_label">Laddar...</span></span>
# 	</button>
# 	<ul class="multiselect-container dropdown-menu" data-js="area_handlebar"></ul>
# </div>
#
# <button tabindex="29" data-ajax-update="false" id="searchbutton" data-js="search_button" class="pull-left featurebox btn btn-primary   plxl prxl pbxs ptxs" type="submit">
# <span data-js="spinner" class="blocket-icon blocket-icon-search"></span>
# </button>
# </div>
# </div>
# <div id="searchbox_right">
#
#
#
# 	<div style="display:none;" class="typebox  form-group pull-left" id="types_right">
# 		<label class="st_label radio-inline" id="label_st_s_right" for="type_s_right" style="display:none"><input data-ajax-update="false" id="type_s_right" type="radio" name="st" value="s" onclick="blocket.apps.searchbox.searchform_submit();" disabled="disabled" tabindex="20" />Säljes&nbsp;</label>
# 		<label class="st_label radio-inline" id="label_st_u_right" for="type_u_right" style="display:none"><input data-ajax-update="false" id="type_u_right" type="radio" name="st" onclick="blocket.apps.searchbox.searchform_submit();" value="u" disabled="disabled" tabindex="20" />Uthyres&nbsp;</label>
# 		<label class="st_label radio-inline" id="label_st_b_right" for="type_b_right" style="display:none"><input data-ajax-update="false" id="type_b_right" type="radio" name="st" onclick="blocket.apps.searchbox.searchform_submit();" value="b" disabled="disabled" tabindex="20" />Bytes&nbsp;</label>
# 		<label class="st_label radio-inline" id="label_st_k_right" for="type_k_right" style="display:none"><input data-ajax-update="false" id="type_k_right" type="radio" name="st" value="k" onclick="blocket.apps.searchbox.searchform_submit();"  disabled="disabled" tabindex="20" />Köpes&nbsp;</label>
# 		<label class="st_label radio-inline" id="label_st_h_right" for="type_h_right" style="display:none"><input data-ajax-update="false" id="type_h_right" type="radio" name="st" value="h" onclick="blocket.apps.searchbox.searchform_submit();" disabled="disabled" tabindex="20" />Önskar hyra&nbsp;</label>
# 		<label class="st_label radio-inline" id="label_st_a_right" for="type_a_right" style="display: none;"><input data-ajax-update="false" id="type_a_right" type="radio" name="st" value="a" onclick="blocket.apps.searchbox.SearchCrit(false, 'a', 'cat');"  disabled="disabled" tabindex="20" />Alla&nbsp;</label>
# 	</div>
#
#
#
# </div>
# <div class="row form-group mbxs">
#
#
#
# <div id="searchextras" class="col-xs-12">
#
#
#
#
# 	<div style="display:block;" class="typebox  form-group pull-left" id="types">
# 		<label class="st_label radio-inline" id="label_st_s" for="type_s" ><input data-ajax-update="false" id="type_s" type="radio" name="st" value="s" onclick="blocket.apps.searchbox.searchform_submit();" checked="checked" tabindex="20" />Säljes&nbsp;</label>
# 		<label class="st_label radio-inline" id="label_st_u" for="type_u" ><input data-ajax-update="false" id="type_u" type="radio" name="st" onclick="blocket.apps.searchbox.searchform_submit();" value="u"  tabindex="20" />Uthyres&nbsp;</label>
# 		<label class="st_label radio-inline" id="label_st_b" for="type_b" ><input data-ajax-update="false" id="type_b" type="radio" name="st" onclick="blocket.apps.searchbox.searchform_submit();" value="b"  tabindex="20" />Bytes&nbsp;</label>
# 		<label class="st_label radio-inline" id="label_st_k" for="type_k" ><input data-ajax-update="false" id="type_k" type="radio" name="st" value="k" onclick="blocket.apps.searchbox.searchform_submit();"   tabindex="20" />Köpes&nbsp;</label>
# 		<label class="st_label radio-inline" id="label_st_h" for="type_h" ><input data-ajax-update="false" id="type_h" type="radio" name="st" value="h" onclick="blocket.apps.searchbox.searchform_submit();"  tabindex="20" />Önskar hyra&nbsp;</label>
# 		<label class="st_label radio-inline" id="label_st_a" for="type_a" style="display: none;"><input data-ajax-update="false" id="type_a" type="radio" name="st" value="a" onclick="blocket.apps.searchbox.SearchCrit(false, 'a', 'cat');"  disabled="disabled" tabindex="20" />Alla&nbsp;</label>
# 	</div>
#
#
#
#
#
# 					<div class="featurebox_col">
# 	<div style="display: none;" id="clothing_sex_0" class="featurebox form-group">
# 		<span class="mll mrl radio_separator">&verbar;</span>
# 		<label class="radio-inline"><input type="radio" name="cs" id="cs_0_0" value="" disabled="disabled"  checked="checked" onclick="blocket.apps.searchbox.SearchCrit(false, false, this.id);blocket.apps.searchbox.reset_value('csz');" tabindex="20" /> Dam &amp; Herr</label>
# 		<label class="radio-inline"><input type="radio" name="cs" id="cs_0_1" value="1" disabled="disabled"  onclick="blocket.apps.searchbox.SearchCrit(false, false, this.id);blocket.apps.searchbox.reset_value('csz');" tabindex="20" /> Dam</label>
# 		<label class="radio-inline"><input type="radio" name="cs" id="cs_0_2" value="2" disabled="disabled"  onclick="blocket.apps.searchbox.SearchCrit(false, false, this.id);blocket.apps.searchbox.reset_value('csz');" tabindex="20" /> Herr</label>
#
# 	</div>
# </div>
#
# <div class="featurebox_col">
# 	<div style="display: none;" id="clothing_sex_1" class="featurebox form-group">
# 		<span class="mll mrl radio_separator">&verbar;</span>
# 		<label class="radio-inline"><input type="radio" name="cs" id="cs_1_0" value="" disabled="disabled"  onclick="blocket.apps.searchbox.SearchCrit(false, false, this.id);blocket.apps.searchbox.reset_value('csz');" /> Flicka &amp; Pojke</label>
# 		<label class="radio-inline"><input type="radio" name="cs" id="cs_1_3" value="3" disabled="disabled"  onclick="blocket.apps.searchbox.SearchCrit(false, false, this.id);blocket.apps.searchbox.reset_value('csz');" /> Flicka</label>
# 		<label class="radio-inline"><input type="radio" name="cs" id="cs_1_4" value="4" disabled="disabled"  onclick="blocket.apps.searchbox.SearchCrit(false, false, this.id);blocket.apps.searchbox.reset_value('csz');" /> Pojke</label>
# 		<label class="radio-inline"><input type="radio" name="cs" id="cs_1_5" value="5" disabled="disabled"  onclick="blocket.apps.searchbox.SearchCrit(false, false, this.id);blocket.apps.searchbox.reset_value('csz');" /> Unisex</label>
#
# 	</div>
# </div>
#
#
#
#
#
#
#
# 		<div class="featurebox_col mrs pricelist">
# 			<div style="display: none;" id="pricelist_0" class="featurebox featurebox_price">
# 			        <div class="btn-group featurebox_dropdown rich_dropdown">
# 			            <label class="btn btn-default mbxs" tabindex="-1">
# 			                <span class="rich-dropdown-label" data-js="rich_dropdown_label">
# 								Pris från
#
# 			                </span>
# 							<select name="ps" class="rich_dropdown" data-swap data-swap-id="ps_0" data-swap-from data-swap-with="pe_0" id="ps_0" disabled="disabled" tabindex="20">
# 								<option value=""  selected="selected">Pris från</option>
#
# 									<option value="0">0</option>
#
# 									<option value="1">5 000</option>
#
# 									<option value="2">10 000</option>
#
# 									<option value="3">20 000</option>
#
# 									<option value="4">30 000</option>
#
# 									<option value="5">40 000</option>
#
# 									<option value="6">50 000</option>
#
# 									<option value="7">60 000</option>
#
# 									<option value="8">70 000</option>
#
# 									<option value="9">80 000</option>
#
# 									<option value="10">90 000</option>
#
# 									<option value="11">100 000</option>
#
# 									<option value="12">110 000</option>
#
# 									<option value="13">120 000</option>
#
# 									<option value="14">130 000</option>
#
# 									<option value="15">140 000</option>
#
# 									<option value="16">150 000</option>
#
# 									<option value="17">160 000</option>
#
# 									<option value="18">170 000</option>
#
# 									<option value="19">180 000</option>
#
# 									<option value="20">190 000</option>
#
# 									<option value="21">200 000</option>
#
# 									<option value="22">210 000</option>
#
# 									<option value="23">220 000</option>
#
# 									<option value="24">230 000</option>
#
# 									<option value="25">240 000</option>
#
# 									<option value="26">250 000</option>
#
# 									<option value="27">260 000</option>
#
# 									<option value="28">270 000</option>
#
# 									<option value="29">280 000</option>
#
# 									<option value="30">290 000</option>
#
# 									<option value="31">300 000</option>
#
# 									<option value="32">350 000</option>
#
# 									<option value="33">400 000</option>
#
# 									<option value="34">450 000</option>
#
# 									<option value="35">500 000</option>
#
# 							</select>
# 			            </label>
# 			        </div>
# 			        <div class="btn-group featurebox_dropdown rich_dropdown">
# 			            <label class="btn btn-default" tabindex="-1">
# 			                <span class="rich-dropdown-label" data-js="rich_dropdown_label">
# 								Pris till
#
# 			                </span>
# 							<select name="pe" class="rich_dropdown" data-swap data-swap-id="pe_0" data-swap-to data-swap-with="ps_0" id="pe_0" disabled="disabled" tabindex="20">
# 								<option value=""  selected="selected">Pris till</option>
#
# 									<option value="1">5 000</option>
#
# 									<option value="2">10 000</option>
#
# 									<option value="3">20 000</option>
#
# 									<option value="4">30 000</option>
#
# 									<option value="5">40 000</option>
#
# 									<option value="6">50 000</option>
#
# 									<option value="7">60 000</option>
#
# 									<option value="8">70 000</option>
#
# 									<option value="9">80 000</option>
#
# 									<option value="10">90 000</option>
#
# 									<option value="11">100 000</option>
#
# 									<option value="12">110 000</option>
#
# 									<option value="13">120 000</option>
#
# 									<option value="14">130 000</option>
#
# 									<option value="15">140 000</option>
#
# 									<option value="16">150 000</option>
#
# 									<option value="17">160 000</option>
#
# 									<option value="18">170 000</option>
#
# 									<option value="19">180 000</option>
#
# 									<option value="20">190 000</option>
#
# 									<option value="21">200 000</option>
#
# 									<option value="22">210 000</option>
#
# 									<option value="23">220 000</option>
#
# 									<option value="24">230 000</option>
#
# 									<option value="25">240 000</option>
#
# 									<option value="26">250 000</option>
#
# 									<option value="27">260 000</option>
#
# 									<option value="28">270 000</option>
#
# 									<option value="29">280 000</option>
#
# 									<option value="30">290 000</option>
#
# 									<option value="31">300 000</option>
#
# 									<option value="32">350 000</option>
#
# 									<option value="33">400 000</option>
#
# 									<option value="34">450 000</option>
#
# 									<option value="35">500 000</option>
#
# 									<option value="36">Över 500 000</option>
#
# 							</select>
# 			            </label>
# 			        </div>
# 				</div>
# 			<div style="display: none;" id="pricelist_1" class="featurebox featurebox_price">
# 			        <div class="btn-group featurebox_dropdown rich_dropdown">
# 			            <label class="btn btn-default mbxs" tabindex="-1">
# 			                <span class="rich-dropdown-label" data-js="rich_dropdown_label">
# 								Pris från
#
# 			                </span>
# 							<select name="ps" class="rich_dropdown" data-swap data-swap-id="ps_1" data-swap-from data-swap-with="pe_1" id="ps_1" disabled="disabled" tabindex="20">
# 								<option value=""  selected="selected">Pris från</option>
#
# 									<option value="0">0</option>
#
# 									<option value="1">5 000</option>
#
# 									<option value="2">10 000</option>
#
# 									<option value="3">20 000</option>
#
# 									<option value="4">30 000</option>
#
# 									<option value="5">40 000</option>
#
# 									<option value="6">50 000</option>
#
# 									<option value="7">60 000</option>
#
# 									<option value="8">70 000</option>
#
# 									<option value="9">80 000</option>
#
# 									<option value="10">90 000</option>
#
# 									<option value="11">100 000</option>
#
# 							</select>
# 			            </label>
# 			        </div>
# 			        <div class="btn-group featurebox_dropdown rich_dropdown">
# 			            <label class="btn btn-default" tabindex="-1">
# 			                <span class="rich-dropdown-label" data-js="rich_dropdown_label">
# 								Pris till
#
# 			                </span>
# 							<select name="pe" class="rich_dropdown" data-swap data-swap-id="pe_1" data-swap-to data-swap-with="ps_1" id="pe_1" disabled="disabled" tabindex="20">
# 								<option value=""  selected="selected">Pris till</option>
#
# 									<option value="1">5 000</option>
#
# 									<option value="2">10 000</option>
#
# 									<option value="3">20 000</option>
#
# 									<option value="4">30 000</option>
#
# 									<option value="5">40 000</option>
#
# 									<option value="6">50 000</option>
#
# 									<option value="7">60 000</option>
#
# 									<option value="8">70 000</option>
#
# 									<option value="9">80 000</option>
#
# 									<option value="10">90 000</option>
#
# 									<option value="11">100 000</option>
#
# 									<option value="12">Över 100 000</option>
#
# 							</select>
# 			            </label>
# 			        </div>
# 				</div>
# 			<div style="display: none;" id="pricelist_2" class="featurebox featurebox_price">
# 			        <div class="btn-group featurebox_dropdown rich_dropdown">
# 			            <label class="btn btn-default mbxs" tabindex="-1">
# 			                <span class="rich-dropdown-label" data-js="rich_dropdown_label">
# 								Pris från
#
# 			                </span>
# 							<select name="ps" class="rich_dropdown" data-swap data-swap-id="ps_2" data-swap-from data-swap-with="pe_2" id="ps_2" disabled="disabled" tabindex="20">
# 								<option value=""  selected="selected">Pris från</option>
#
# 									<option value="0">0</option>
#
# 									<option value="1">2 500</option>
#
# 									<option value="2">5 000</option>
#
# 									<option value="3">7 500</option>
#
# 									<option value="4">10 000</option>
#
# 									<option value="5">12 500</option>
#
# 									<option value="6">15 000</option>
#
# 									<option value="7">17 500</option>
#
# 									<option value="8">20 000</option>
#
# 									<option value="9">22 500</option>
#
# 									<option value="10">25 000</option>
#
# 									<option value="11">27 500</option>
#
# 									<option value="12">30 000</option>
#
# 							</select>
# 			            </label>
# 			        </div>
# 			        <div class="btn-group featurebox_dropdown rich_dropdown">
# 			            <label class="btn btn-default" tabindex="-1">
# 			                <span class="rich-dropdown-label" data-js="rich_dropdown_label">
# 								Pris till
#
# 			                </span>
# 							<select name="pe" class="rich_dropdown" data-swap data-swap-id="pe_2" data-swap-to data-swap-with="ps_2" id="pe_2" disabled="disabled" tabindex="20">
# 								<option value=""  selected="selected">Pris till</option>
#
# 									<option value="1">2 500</option>
#
# 									<option value="2">5 000</option>
#
# 									<option value="3">7 500</option>
#
# 									<option value="4">10 000</option>
#
# 									<option value="5">12 500</option>
#
# 									<option value="6">15 000</option>
#
# 									<option value="7">17 500</option>
#
# 									<option value="8">20 000</option>
#
# 									<option value="9">22 500</option>
#
# 									<option value="10">25 000</option>
#
# 									<option value="11">27 500</option>
#
# 									<option value="12">30 000</option>
#
# 									<option value="13">Över 30 000</option>
#
# 							</select>
# 			            </label>
# 			        </div>
# 				</div>
# 			<div style="display: none;" id="pricelist_3" class="featurebox featurebox_price">
# 			        <div class="btn-group featurebox_dropdown rich_dropdown">
# 			            <label class="btn btn-default mbxs" tabindex="-1">
# 			                <span class="rich-dropdown-label" data-js="rich_dropdown_label">
# 								Pris från
#
# 			                </span>
# 							<select name="ps" class="rich_dropdown" data-swap data-swap-id="ps_3" data-swap-from data-swap-with="pe_3" id="ps_3" disabled="disabled" tabindex="20">
# 								<option value=""  selected="selected">Pris från</option>
#
# 									<option value="0">0</option>
#
# 									<option value="1">100 000</option>
#
# 									<option value="2">200 000</option>
#
# 									<option value="3">300 000</option>
#
# 									<option value="4">400 000</option>
#
# 									<option value="5">500 000</option>
#
# 									<option value="6">750 000</option>
#
# 									<option value="7">1 000 000</option>
#
# 									<option value="8">1 250 000</option>
#
# 									<option value="9">1 500 000</option>
#
# 									<option value="10">1 750 000</option>
#
# 									<option value="11">2 000 000</option>
#
# 									<option value="12">2 250 000</option>
#
# 									<option value="13">2 500 000</option>
#
# 									<option value="14">3 000 000</option>
#
# 									<option value="15">3 500 000</option>
#
# 									<option value="16">4 000 000</option>
#
# 									<option value="17">4 500 000</option>
#
# 									<option value="18">5 000 000</option>
#
# 									<option value="19">5 500 000</option>
#
# 									<option value="20">6 000 000</option>
#
# 									<option value="21">6 500 000</option>
#
# 									<option value="22">7 000 000</option>
#
# 									<option value="23">8 000 000</option>
#
# 									<option value="24">9 000 000</option>
#
# 									<option value="25">10 000 000</option>
#
# 									<option value="26">12 000 000</option>
#
# 									<option value="27">15 000 000</option>
#
# 							</select>
# 			            </label>
# 			        </div>
# 			        <div class="btn-group featurebox_dropdown rich_dropdown">
# 			            <label class="btn btn-default" tabindex="-1">
# 			                <span class="rich-dropdown-label" data-js="rich_dropdown_label">
# 								Pris till
#
# 			                </span>
# 							<select name="pe" class="rich_dropdown" data-swap data-swap-id="pe_3" data-swap-to data-swap-with="ps_3" id="pe_3" disabled="disabled" tabindex="20">
# 								<option value=""  selected="selected">Pris till</option>
#
# 									<option value="1">100 000</option>
#
# 									<option value="2">200 000</option>
#
# 									<option value="3">300 000</option>
#
# 									<option value="4">400 000</option>
#
# 									<option value="5">500 000</option>
#
# 									<option value="6">750 000</option>
#
# 									<option value="7">1 000 000</option>
#
# 									<option value="8">1 250 000</option>
#
# 									<option value="9">1 500 000</option>
#
# 									<option value="10">1 750 000</option>
#
# 									<option value="11">2 000 000</option>
#
# 									<option value="12">2 250 000</option>
#
# 									<option value="13">2 500 000</option>
#
# 									<option value="14">3 000 000</option>
#
# 									<option value="15">3 500 000</option>
#
# 									<option value="16">4 000 000</option>
#
# 									<option value="17">4 500 000</option>
#
# 									<option value="18">5 000 000</option>
#
# 									<option value="19">5 500 000</option>
#
# 									<option value="20">6 000 000</option>
#
# 									<option value="21">6 500 000</option>
#
# 									<option value="22">7 000 000</option>
#
# 									<option value="23">8 000 000</option>
#
# 									<option value="24">9 000 000</option>
#
# 									<option value="25">10 000 000</option>
#
# 									<option value="26">12 000 000</option>
#
# 									<option value="27">15 000 000</option>
#
# 									<option value="28">15 000 000+</option>
#
# 							</select>
# 			            </label>
# 			        </div>
# 				</div>
# 			<div style="display: none;" id="pricelist_4" class="featurebox featurebox_price">
# 			        <div class="btn-group featurebox_dropdown rich_dropdown">
# 			            <label class="btn btn-default mbxs" tabindex="-1">
# 			                <span class="rich-dropdown-label" data-js="rich_dropdown_label">
# 								Pris från
#
# 			                </span>
# 							<select name="ps" class="rich_dropdown" data-swap data-swap-id="ps_4" data-swap-from data-swap-with="pe_4" id="ps_4" disabled="disabled" tabindex="20">
# 								<option value=""  selected="selected">Pris från</option>
#
# 									<option value="0">0</option>
#
# 									<option value="1">5 000</option>
#
# 									<option value="2">10 000</option>
#
# 									<option value="3">20 000</option>
#
# 									<option value="4">30 000</option>
#
# 									<option value="5">40 000</option>
#
# 									<option value="6">50 000</option>
#
# 									<option value="7">60 000</option>
#
# 									<option value="8">70 000</option>
#
# 									<option value="9">80 000</option>
#
# 									<option value="10">90 000</option>
#
# 									<option value="11">100 000</option>
#
# 									<option value="12">110 000</option>
#
# 									<option value="13">120 000</option>
#
# 									<option value="14">130 000</option>
#
# 									<option value="15">140 000</option>
#
# 									<option value="16">150 000</option>
#
# 									<option value="17">160 000</option>
#
# 									<option value="18">170 000</option>
#
# 									<option value="19">180 000</option>
#
# 									<option value="20">190 000</option>
#
# 									<option value="21">200 000</option>
#
# 									<option value="22">210 000</option>
#
# 									<option value="23">220 000</option>
#
# 									<option value="24">230 000</option>
#
# 									<option value="25">240 000</option>
#
# 									<option value="26">250 000</option>
#
# 									<option value="27">260 000</option>
#
# 									<option value="28">270 000</option>
#
# 									<option value="29">280 000</option>
#
# 									<option value="30">290 000</option>
#
# 									<option value="31">300 000</option>
#
# 									<option value="32">350 000</option>
#
# 									<option value="33">400 000</option>
#
# 									<option value="34">450 000</option>
#
# 									<option value="35">500 000</option>
#
# 									<option value="36">550 000</option>
#
# 									<option value="37">600 000</option>
#
# 									<option value="38">650 000</option>
#
# 									<option value="39">700 000</option>
#
# 									<option value="40">750 000</option>
#
# 									<option value="41">800 000</option>
#
# 									<option value="42">850 000</option>
#
# 									<option value="43">900 000</option>
#
# 									<option value="44">950 000</option>
#
# 									<option value="45">1 000 000</option>
#
# 									<option value="46">1 200 000</option>
#
# 									<option value="47">1 400 000</option>
#
# 									<option value="48">1 600 000</option>
#
# 									<option value="49">1 800 000</option>
#
# 									<option value="50">2 000 000</option>
#
# 							</select>
# 			            </label>
# 			        </div>
# 			        <div class="btn-group featurebox_dropdown rich_dropdown">
# 			            <label class="btn btn-default" tabindex="-1">
# 			                <span class="rich-dropdown-label" data-js="rich_dropdown_label">
# 								Pris till
#
# 			                </span>
# 							<select name="pe" class="rich_dropdown" data-swap data-swap-id="pe_4" data-swap-to data-swap-with="ps_4" id="pe_4" disabled="disabled" tabindex="20">
# 								<option value=""  selected="selected">Pris till</option>
#
# 									<option value="1">5 000</option>
#
# 									<option value="2">10 000</option>
#
# 									<option value="3">20 000</option>
#
# 									<option value="4">30 000</option>
#
# 									<option value="5">40 000</option>
#
# 									<option value="6">50 000</option>
#
# 									<option value="7">60 000</option>
#
# 									<option value="8">70 000</option>
#
# 									<option value="9">80 000</option>
#
# 									<option value="10">90 000</option>
#
# 									<option value="11">100 000</option>
#
# 									<option value="12">110 000</option>
#
# 									<option value="13">120 000</option>
#
# 									<option value="14">130 000</option>
#
# 									<option value="15">140 000</option>
#
# 									<option value="16">150 000</option>
#
# 									<option value="17">160 000</option>
#
# 									<option value="18">170 000</option>
#
# 									<option value="19">180 000</option>
#
# 									<option value="20">190 000</option>
#
# 									<option value="21">200 000</option>
#
# 									<option value="22">210 000</option>
#
# 									<option value="23">220 000</option>
#
# 									<option value="24">230 000</option>
#
# 									<option value="25">240 000</option>
#
# 									<option value="26">250 000</option>
#
# 									<option value="27">260 000</option>
#
# 									<option value="28">270 000</option>
#
# 									<option value="29">280 000</option>
#
# 									<option value="30">290 000</option>
#
# 									<option value="31">300 000</option>
#
# 									<option value="32">350 000</option>
#
# 									<option value="33">400 000</option>
#
# 									<option value="34">450 000</option>
#
# 									<option value="35">500 000</option>
#
# 									<option value="36">550 000</option>
#
# 									<option value="37">600 000</option>
#
# 									<option value="38">650 000</option>
#
# 									<option value="39">700 000</option>
#
# 									<option value="40">750 000</option>
#
# 									<option value="41">800 000</option>
#
# 									<option value="42">850 000</option>
#
# 									<option value="43">900 000</option>
#
# 									<option value="44">950 000</option>
#
# 									<option value="45">1 000 000</option>
#
# 									<option value="46">1 200 000</option>
#
# 									<option value="47">1 400 000</option>
#
# 									<option value="48">1 600 000</option>
#
# 									<option value="49">1 800 000</option>
#
# 									<option value="50">2 000 000</option>
#
# 									<option value="51">Över 2 000 000</option>
#
# 							</select>
# 			            </label>
# 			        </div>
# 				</div>
# 			<div style="display: none;" id="pricelist_5" class="featurebox featurebox_price">
# 			        <div class="btn-group featurebox_dropdown rich_dropdown">
# 			            <label class="btn btn-default mbxs" tabindex="-1">
# 			                <span class="rich-dropdown-label" data-js="rich_dropdown_label">
# 								Pris från
#
# 			                </span>
# 							<select name="ps" class="rich_dropdown" data-swap data-swap-id="ps_5" data-swap-from data-swap-with="pe_5" id="ps_5" disabled="disabled" tabindex="20">
# 								<option value=""  selected="selected">Pris från</option>
#
# 									<option value="0">0</option>
#
# 									<option value="1">100 000</option>
#
# 									<option value="2">200 000</option>
#
# 									<option value="3">300 000</option>
#
# 									<option value="4">400 000</option>
#
# 									<option value="5">500 000</option>
#
# 									<option value="6">750 000</option>
#
# 									<option value="7">1 000 000</option>
#
# 									<option value="8">1 500 000</option>
#
# 									<option value="9">2 000 000</option>
#
# 									<option value="10">2 500 000</option>
#
# 									<option value="11">3 000 000</option>
#
# 									<option value="12">3 500 000</option>
#
# 									<option value="13">4 000 000</option>
#
# 									<option value="14">5 000 000</option>
#
# 									<option value="15">6 000 000</option>
#
# 									<option value="16">7 000 000</option>
#
# 									<option value="17">8 000 000</option>
#
# 									<option value="18">9 000 000</option>
#
# 							</select>
# 			            </label>
# 			        </div>
# 			        <div class="btn-group featurebox_dropdown rich_dropdown">
# 			            <label class="btn btn-default" tabindex="-1">
# 			                <span class="rich-dropdown-label" data-js="rich_dropdown_label">
# 								Pris till
#
# 			                </span>
# 							<select name="pe" class="rich_dropdown" data-swap data-swap-id="pe_5" data-swap-to data-swap-with="ps_5" id="pe_5" disabled="disabled" tabindex="20">
# 								<option value=""  selected="selected">Pris till</option>
#
# 									<option value="1">100 000</option>
#
# 									<option value="2">200 000</option>
#
# 									<option value="3">300 000</option>
#
# 									<option value="4">400 000</option>
#
# 									<option value="5">500 000</option>
#
# 									<option value="6">750 000</option>
#
# 									<option value="7">1 000 000</option>
#
# 									<option value="8">1 500 000</option>
#
# 									<option value="9">2 000 000</option>
#
# 									<option value="10">2 500 000</option>
#
# 									<option value="11">3 000 000</option>
#
# 									<option value="12">3 500 000</option>
#
# 									<option value="13">4 000 000</option>
#
# 									<option value="14">5 000 000</option>
#
# 									<option value="15">6 000 000</option>
#
# 									<option value="16">7 000 000</option>
#
# 									<option value="17">8 000 000</option>
#
# 									<option value="18">9 000 000</option>
#
# 									<option value="19">Över 9 000 000</option>
#
# 							</select>
# 			            </label>
# 			        </div>
# 				</div>
#
# 		</div>
#
#
#
#
#
#
#
# <div class="featurebox_col mrs">
# 		<div style="display: none;" id="regdate" class="featurebox featurebox_regdate">
# 	        <div class="btn-group featurebox_dropdown rich_dropdown">
# 	            <label class="btn btn-default mbxs" tabindex="-1">
# 	                <span class="rich-dropdown-label" data-js="rich_dropdown_label">
# 						Modellår från
#
# 	                </span>
# ...
# 				loadtype: "rsi_segs",
# 				lazyload: "0",
# 				params: "ADTECH;alias=blocketd_listning_li_post_it_4;loc=100;target=_blank;kvsearchword=macbook%20air;kvcounty=11",
# 				width: 221,
# 				height: 0,
# 				hash_override_enabled: 1,
# 				source: 0,
# 				bootstrap: 0
# 			};
# 			blocket.apps.common.placements.push(data);
# 		</script>
#
#
#
#
#
#
#
# 				<article id="latest_search">
# 	<div id="latest_search_container" class="hidden">
# 		<h1 class="h6 param_title">
# 			Dina senaste sökningar
# 		</h1>
# 		<ul id="latest_search_item_container" class="list-unstyled">
# 			<li class="latest_search_wrapper pbxs hidden">
# 				<div class="latest_search_link">
# 					<a href="#" onclick="return xt_click(this, 'F', '', 'Sokningar');" class="latest_search_text_link navigation_link">
# 						<i class="blocket-icon blocket-icon-search prxs"></i><span data-js="searchword">Sökhistorik</span>
# 					</a>
# 				</div>
# 			</li>
# 		</ul>
# 	</div>
# </article>
#
#
#
#
#
# 				<article id="last_viewed">
# 	<div id="last_viewed_container" class="hidden">
# 		<h1 class="h6 param_title">
# 			Senast tittat på
# 		</h1>
# 		<article id="last_viewed_image_container" class="list-unstyled" itemscope itemtype="http://schema.org/ImageGallery">
# 			<figure class="image_wrapper hidden col-xs-4 nopadding" itemprop="image" itemscope itemtype="http://schema.org/ImageObject">
# 				<a href="" itemprop="contentURL" onclick="return xt_click(this, 'F', '', 'Tittat pa');">
# 					<img src="https://www.blocket.com/img/transparent.gif" itemprop="thumbnailUrl" class="image" alt="">
# 				</a>
# 			</figure>
# 		</article>
# 	</div>
# </article>
#
#
#
#
#
#
#
#
# 		</aside>
#
#
#
# 	</div>
#
# 	        <div id="bottom_panorama_container">
#
# <div class="row"><article id="bottom_panorama" data-js-placement="bottom_panorama" class="col-xs-12"></article></div>
# <script>
# 	data = {
# 		id:"bottom_panorama",
# 		loadtype: "normal_iframe",
# 		lazyload: "1",
# 		params: "https://jobb.blocket.se/blocket_puff.html?jparent_appl=li_footer&jw=1&jca=11#bottom_panorama_iframe",
# 		width: 980,
# 		height:0
# 	}
# 	blocket.apps.common.placements.push(data);
# </script>
#
#
# 	        </div>
#
#
#
# </div>
#
#
#
#
#
# </div>
# <footer id="blocket_footer" class="row" data-print="no">
#
# 	<div class="col-xs-12 background-primary">
# 		<div class="row">
# 			<div class="col-xs-12">
# 				<hr>
# 			</div>
# 		</div>
# 		<div class="row pbxl">
# 			<nav class="col-xs-3">
#
# 				<h6>Kundservice</h6>
# 				<ul class="footer-list">
#
# 					<li class="pbs"><a href="https://blocket.zendesk.com" >Kontakta oss</a></li>
#
# 					<li class="pbs"><a href="https://www.blocket.se/apps/support?id=11" >Butikssupport</a></li>
#
# 					<li class="pbs"><a href="http://www.blocket.se/kundsakerhet.htm" >Kundsäkerhet</a></li>
#
# 					<li class="pbs"><a href="http://www.blocket.se/marketing/marketing_salehints.html" >Säljtips</a></li>
#
# 				</ul>
# 			</nav>
# 			<nav class="col-xs-3">
#
# 				<h6>Hjälp vid affärer</h6>
# 				<ul class="footer-list">
#
# 					<li class="pbs">
#
# 						<a href="http://www.blocket.se/blocketpaketet/blocketpaketet.htm" >Blocketpaketet</a></li>
#
# 					<li class="pbs">
#
# 						<a href="https://trustly.com/blocket/about" >Direktbetalning</a></li>
#
# 					<li class="pbs">
#
# 						<a href="http://www.blocket.se/security/mallar.htm" >Köpekontrakt</a></li>
#
# 					<li class="pbs">
#
# 						<a href="http://www.blocket.se/insurances/bbf.htm" >Begagnatförsäkring</a></li>
#
# 					<li class="pbs">
#
# 							<img src="https://www.blocket.com/img/transparent.gif" class="sprite_common_blocketpaketet_logo" alt="Betala Blocketpaketet" title="">
#
#
# 						<a href="http://www.blocket.se/blocketpaketet/betalning.htm" >Betala Blocketpaketet</a></li>
#
# 					<li class="pbs">
#
# 							<img src="https://www.blocket.com/img/transparent.gif" class="sprite_common_icon_trustly_small" alt="Ta emot Direktbetalning" title="">
#
#
# 						<a href="https://trustly.com/blocket/accept" >Ta emot Direktbetalning</a></li>
#
# 				</ul>
# 			</nav>
# 			<nav class="col-xs-3">
#
# 				<h6>Information</h6>
# 				<ul class="footer-list">
#
# 					<li class="pbs"><a href="http://www.blocket.se/omblocket.htm" >Om Blocket</a></li>
#
# 					<li class="pbs"><a href="http://www.blocket.se/hallbarhetsarbete" >Vårt hållbarhetsarbete</a></li>
#
# 					<li class="pbs"><a href="https://www.blocket.se/apps/support?id=10" >Press</a></li>
#
# 					<li class="pbs"><a href="http://www.blocketpanelen.se/?referer=blocket.se&utm_source=blocket.se&utm_medium=hemsida&utm_campaign=blocket.se" >Blocketpanelen</a></li>
#
# 					<li class="pbs"><a href="http://www.blocket.se/karriar.html" >Jobba på Blocket</a></li>
#
# 					<li class="pbs"><a href="http://www.facebook.com/blocket.se" >Blocket på Facebook</a></li>
#
# 					<li class="pbs"><a href="http://www.blocket.se/spid.htm" >Logga in med SPiD</a></li>
#
# 					<li class="pbs"><a href="http://www.blocket.se/personuppgiftspolicy.htm" >Personuppgiftshantering</a></li>
#
# 					<li class="pbs"><a href="http://www.blocket.se/cookiepolicy.htm" >Cookiepolicy</a></li>
#
# 				</ul>
# 			</nav>
# 			<nav class="col-xs-3">
#
# 				<h6>Marknadsföring</h6>
# 				<ul class="footer-list">
#
# 					<li class="pbs"><a href="https://www.blocketsannonswebb.se/" >Annonswebben</a></li>
#
# 					<li class="pbs"><a href="https://www.blocketsannonswebb.se/butik_pa_blocket.html" >Öppna butik på Blocket</a></li>
#
# 					<li class="pbs"><a href="http://www.blocket.se/stockholm?ca=11&amp;fk=1" >Visa alla butiker på Blocket</a></li>
#
# 					<li class="pbs"><a href="https://www.blocket.se/store/login"  onclick="xt_med('C', '', 'Logga_in_i_butiken_footer', 'N');">Inloggning för butiker</a></li>
#
# 				</ul>
# 			</nav>
# 		</div>
#
# 	</div>
# </footer>
#
#
#
# </section> <!-- /div#blocket -->
#
#
#
# <script type="text/javascript">
# blocket("@params.base_url").extend({
# ai: "https://www.blocket.se"
# });
# </script>
#
#
# <script src="/js/7db7ae4718b2c5d642013c0444a49116/list.js" type="text/javascript"></script>
#
#
#
# <script src="/js/ee1065768332e4a8a484c010f8d1284d/campaigns.js" type="text/javascript"></script>
# <script type="text/javascript">
# jQuery(document).ready(function() {
# blocket.init.base();
# });
# </script>
#
#
#
#
#
# <script id="pulse" type="text/javascript">
# 	var _opt = {
# 		pageId: "li",
# 		clientId: "blocket",
#
#
# 		contentType: "Listing",
#
# 		provider: {
# 			category: ""
# 		},
# 		trackingFeatures: {
# 			pageLoad: true,            // Default: true
# 			hashChange: false,          // Default: true
# 			pageUnload: false,         // Default: true (This is an experimental feature)
# 			clickButton: false,         // Default: true
# 			clickSubmit: false,         // Default: true
# 			relativeScroll: false,      // Default: true
# 			itemVisible: false,         // Default: true
# 			facebook: false,           // Default: true (Requires Facebook Javascript SDK)
# 			twitter: false             // Default: true
# 		}
# 	};
#
# 	/*
# 	GitHub repo and documentation:
# 	https://github.com/schibsted/sdk-js-event-tracking-contrib
# 	*/
#
# 		(function(){
# 		var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0];
# 		g.src="//d1nf1ogr7o23z7.cloudfront.net/autoTrackerBlocket.min.js";
# 		s.parentNode.insertBefore(g,s);
# 		}());
#
# </script>
#
# <script src="/js/49476736396b8208d93ac1a4cd31c7cd/advertisement.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	var has_adblock = function(){
# 		var el = document.getElementById("adblock_detect");
# 		if (typeof el === "undefined" || el === null || el === "") {
#
# 			return true;
# 		}
# 		return false;
# 	}
# </script>
#
#
# <script id="xiti_tag" type="text/javascript">
#
# //<!-- XITI TAGGING -->
# xtnv = document;
#
# xtsd = "http://logc89";
#
# xtsite = "379341";
# xtn2 = "11";
# xtpage = "Search::listing_all";
# xtdi = "";
#
#
#
# xt_mtcl = "catall_macbook_air";
# xt_npg = "1";
#
# if (window.xtparam!=null){window.xtparam+="&mc="+xt_mtcl+"&np="+xt_npg;}
# else{window.xtparam ="&mc="+xt_mtcl+"&np="+xt_npg;};
#
#
#
#
#
#
#
#
# xt_multc = "&x9=2";
#
#
#
#
#
#
# if (typeof(xt_multc) == "undefined") {
# xt_multc = '&x11=0';
# } else {
# xt_multc += '&x11=0';
# }
#
# xt_multc += '&x14=0';
#
#
#
# xt_multc += "&x19=0";
#
#
# if (typeof has_adblock === "function") {
# if (has_adblock()) {
# xt_multc += '&x18=1';
# } else {
# xt_multc += '&x18=0';
# }
# }
#
#
#
# var badges ="";
#
#
#
#
# xt_multc += "&x21=";
# xt_multc += badges;
# if (window.xtparam!=null) {
# window.xtparam+=xt_multc;
# } else{
# window.xtparam =xt_multc;
# }
#
# //<!-- END XITI TAGGING -->
#
# </script>
# <script type="text/javascript" src="/js/83ca5bd671b05e0141e4cb94faa262f5/xtcore.js"></script>
#
# <noscript>
#
# <img width="1" height="1" alt="" src="http://logc89.xiti.com/hit.xiti?s=379341&s2=11&p=Search::listing_all&di=&x9=2" >
#
# </noscript>
#
#
#
# 	<!-- SIFO panel -->
#
# 	<!-- begin oas Panel Only tag -->
#
# 	<iframe id="sifo_panel_iframe" src="http://www.blocket.se/_blank.html" style="display:none;"></iframe>
#
#
# 	<!-- endoas Panel Only tag -->
#
#
#
#
#
#
#
#
#
#
#
#
# <!-- Adform Tracking Code BEGIN -->
# <script type="text/javascript">
# 	var _adftrack = {
# 		pm: 288867,
# 		divider: encodeURIComponent('|'),
# 		pagename: encodeURIComponent('Blocket.se setup 2015-03-20|blocket.se|category|subcategory|category pages'),
# 		order : {
# 			 sv1: '11',
# 			 sv2: 'macbook%20air',
# 			 sv6: ''
# 		}
# 	};
# 	(function () { var s = document.createElement('script'); s.type = 'text/javascript'; s.async = true; s.src = 'https://track.adform.net/serving/scripts/trackpoint/async/'; var x = document.getElementsByTagName('script')[0]; x.parentNode.insertBefore(s, x); })();
#
# </script>
# <noscript>
# 	<p style="margin:0;padding:0;border:0;">
# 		<img src="https://track.adform.net/Serving/TrackPoint/?pm=288867&ADFPageName=Blocket.se%20setup%202015-03-20%7Cblocket.se%7Ccategory%7Csubcategory%7Ccategory%20pages&ADFdivider=|" width="1" height="1" alt="" />
# 	</p>
# </noscript>
# <!-- Adform Tracking Code END -->
#
#
#
#
#
# <!-- js_globals new -->
#
# <script type="text/javascript">
#
#
#
# 	blocket('@params').extend({
# 		application : "list",
#
# 		regress : 0,
#
# 		protocol : "http"
# 	});
#
# </script>
#
# <script type="text/javascript" src="/templates/common/arrays_v2.js?lang=sv&amp;94677"></script>
#
# <script type="text/javascript">
#
#
# blocket("@params").extend({latest_search: {
# 			limit : 5,
# 			local_storage_name : "latest_search",
# 			enabled : "1",
# 			search_query : "macbook air",
# 			category : "",
# 			no_thumb_url : "/img/list/no_thumb_last_viewed.png"
# 		}});
#
# 		jQuery(document).ready(function() {
#
#
#
# 			blocket.apps.common.lazy_load_content(jQuery("#latest_search"), function() {
# 				blocket.apps.list.run_latest_search();
# 			},"latest_search");
# 		});
#
# jQuery(document).ready(function() {
# 			blocket.apps.common.lazy_load_content(jQuery("#last_viewed"), function() {
# 				blocket.apps.list.run_last_viewed();
# 			},"lazy_last_viewed_ads");
# 		});
#
#
# 		blocket("@params").extend({
# 			ajax: {
# 				li:       {  "area": [	{		"name": "Botkyrka",		"value": 116,		"hits": 					1				,		"subarea": [					],		"xt_name": "kommun_all"	}	,{		"name": "Danderyd",		"value": 117,		"hits": 					2				,		"subarea": [					],		"xt_name": "kommun_all"	}	,{		"name": "Ekerö",		"value": 118,		"hits": 0				,		"subarea": [					],		"xt_name": "kommun_all"	}	,{		"name": "Haninge",		"value": 119,		"hits": 					1				,		"subarea": [					],		"xt_name": "kommun_all"	}	,{		"name": "Huddinge",		"value": 120,		"hits": 0				,		"subarea": [					],		"xt_name": "kommun_all"	}	,{		"name": "Järfälla",		"value": 121,		"hits": 					3				,		"subarea": [					],		"xt_name": "kommun_all"	}	,{		"name": "Lidingö",		"value": 122,		"hits": 					2				,		"subarea": [					],		"xt_name": "kommun_all"	}	,{		"name": "Nacka",		"value": 123,		"hits": 					1				,		"subarea": [					],		"xt_name": "kommun_all"	}	,{		"name": "Norrtälje",		"value": 124,		"hits": 0				,		"subarea": [					],		"xt_name": "kommun_all"	}	,{		"name": "Nykvarn",		"value": 125,		"hits": 0				,		"subarea": [					],		"xt_name": "kommun_all"	}	,{		"name": "Nynäshamn",		"value": 126,		"hits": 0				,		"subarea": [					],		"xt_name": "kommun_all"	}	,{		"name": "Salem",		"value": 127,		"hits": 0				,		"subarea": [					],		"xt_name": "kommun_all"	}	,{		"name": "Sigtuna",		"value": 128,		"hits": 					1				,		"subarea": [					],		"xt_name": "kommun_all"	}	,{		"name": "Sollentuna",		"value": 129,		"hits": 0				,		"subarea": [					],		"xt_name": "kommun_all"	}	,{		"name": "Solna",		"value": 130,		"hits": 					2				,		"subarea": [					],		"xt_name": "kommun_all"	}	,{		"name": "Stockholms stad",		"value": 131,		"hits": 					40				,		"subarea": [			{				"name": "Bromma",				"value": 1,				"hits": 							1									}			,{				"name": "Enskede, Årsta, Skarpnäck",				"value": 2,				"hits": 							4									}			,{				"name": "Hägersten, Liljeholmen",				"value": 3,				"hits": 							3									}			,{				"name": "Katarina, Sofia",				"value": 4,				"hits": 							4									}			,{				"name": "Kista, Hässelby, Vällingby, Spånga",				"value": 5,				"hits": 							2									}			,{				"name": "Kungsholmen",				"value": 6,				"hits": 							2									}			,{				"name": "Maria, Gamla Stan, Högalid",				"value": 7,				"hits": 							2									}			,{				"name": "Skärholmen, Bredäng",				"value": 8,				"hits": 							2									}			,{				"name": "Vasastan, Norrmalm",				"value": 9,				"hits": 							7									}			,{				"name": "Älvsjö, Farsta, Vantör",				"value": 10,				"hits": 							6									}			,{				"name": "Östermalm, Djurgården",				"value": 11,				"hits": 							7									}					],		"xt_name": "kommun_all"	}	,{		"name": "Sundbyberg",		"value": 132,		"hits": 0				,		"subarea": [					],		"xt_name": "kommun_all"	}	,{		"name": "Södertälje",		"value": 133,		"hits": 					2				,		"subarea": [					],		"xt_name": "kommun_all"	}	,{		"name": "Tyresö",		"value": 134,		"hits": 0				,		"subarea": [					],		"xt_name": "kommun_all"	}	,{		"name": "Täby",		"value": 135,		"hits": 0				,		"subarea": [					],		"xt_name": "kommun_all"	}	,{		"name": "Upplands Väsby",		"value": 136,		"hits": 					2				,		"subarea": [					],		"xt_name": "kommun_all"	}	,{		"name": "Upplands-Bro",		"value": 137,		"hits": 					1				,		"subarea": [					],		"xt_name": "kommun_all"	}	,{		"name": "Vallentuna",		"value": 138,		"hits": 0				,		"subarea": [					],		"xt_name": "kommun_all"	}	,{		"name": "Vaxholm",		"value": 139,		"hits": 0				,		"subarea": [					],		"xt_name": "kommun_all"	}	,{		"name": "Värmdö",		"value": 140,		"hits": 0				,		"subarea": [					],		"xt_name": "kommun_all"	}	,{		"name": "Österåker",		"value": 141,		"hits": 0				,		"subarea": [					],		"xt_name": "kommun_all"	}	],  "linkshelf": {    "verticals": {        "jobb": {            "name": "Jobb",            "url": "https://jobb.blocket.se/index.html"        },        "bostad": {            "name": "Bostad",            "url": "http://www.blocket.se/bostad?ca=11&w=1"        }    },    "filter" :[        {"name" ...
# 				rtype: "area,linkshelf"
# 			}
# 		});
#
#
# blocket("@params").extend({q:"macbook air",previous_ads:{limit:9,local_storage_name:"last_viewed_ads",enabled:"1"}});
# blocket.common.onload_queue.add( {
# 			onload_function : function (obj) {
# 				if(document.cookie.indexOf('member_type=') === -1) {
# 					var OAS_server = 'http://oasc00454.247realmedia.com';
# 					if(!(OAS_rn)) {
# 						var OAS_rn = new String (Math.random());
# 						var OAS_rns = OAS_rn.substring (2, 11);
# 					}
# 					var OAS_taxonomy='&Sajt=blocket.se&Sektion=';
#
# 					var sifoframe = document.getElementById("sifo_panel_iframe");
# 					if (typeof(sifoframe.contentWindow) == "undefined") {
# 						jQuery(sifoframe).load(function() {
# 							sifoframe.contentWindow.location.replace( 'http://panel2.research-int.se/0/RI-Panel/pixel/set_panel2.html?'+OAS_rns+'__!__'+OAS_server+'__!__'+OAS_taxonomy );
# 						});
# 					} else {
# 						sifoframe.contentWindow.location.replace( 'http://panel2.research-int.se/0/RI-Panel/pixel/set_panel2.html?'+OAS_rns+'__!__'+OAS_server+'__!__'+OAS_taxonomy );
# 					}
# 					return true;
# 				}
# 			}
# 		},'medium');
#
#
#
# </script>
#
#
#
# <noscript><img src="/img/.1461933670.8692/none.gif" alt="" /></noscript>
# <script>
#
# </script>
#
#
#
# </body>
# </html>
#
#
#
# <!-- sbw13 53972 -->

# %% [markdown]
# ### Our research for buying a new computer
#
# #### Here we parse the html to a format which we can use

# %%
import lxml.html

page = lxml.html.parse("http://www.blocket.se/stockholm?q=macbook")
# This is probably illegal. Do not use at all
items_data = []
for el in page.getroot().find_class("media item_row ptm pbm nmt"):
    links = el.find_class("item_link")
    images = el.find_class("item_image")
    prices = el.find_class("list_price")
    if links and images and prices and prices[0].text:
        items_data.append({"name": links[0].text,
                           "image": images[0].attrib['src'],
                           "price": int(prices[0].text.split(":")[0].replace(" ", ""))})
print(len(items_data))
items_data
# Out:
# 7
# [{'image': 'https://cdn.blocket.com/static/0/lithumbs/20/2050737109.jpg',
#   'name': 'Macbook pro',
#   'price': 9000},
#  {'image': 'https://cdn.blocket.com/static/1/lithumbs/20/2062346621.jpg',
#   'name': 'IMac 27"',
#   'price': 11000},
#  {'image': 'https://cdn.blocket.com/static/1/lithumbs/20/2014054699.jpg',
#   'name': 'MacBook PRO 8gb ram 512 GB sed sent 2013',
#   'price': 7200},
#  {'image': 'https://cdn.blocket.com/static/1/lithumbs/20/2027826471.jpg',
#   'name': 'MacBook PRO, 13# Retina Display, 2014',
#   'price': 10500},
#  {'image': 'https://cdn.blocket.com/static/0/lithumbs/19/1908508402.jpg',
#   'name': 'MacBook 12 (guld) Intel core m',
#   'price': 12000},
#  {'image': 'https://cdn.blocket.com/static/2/lithumbs/00/0055866749.jpg',
#   'name': 'Apple MacBook - 12" Retina - 1,2GHz 8GB 512GB',
#   'price': 13000},
#  {'image': 'https://cdn.blocket.com/static/0/lithumbs/19/1971380423.jpg',
#   'name': 'MacBook 13 tum - i5 - 128 GB SSD - 8 GB ram',
#   'price': 4500}]

# %%
# %matplotlib inline
prices = []
prices_for_retina = []
for item in items_data:
    prices.append(item['price'])
    if 'Retina' in item['name']:
        prices_for_retina.append(item['price'])
    
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
plt.hist(prices, 5, histtype='bar')
plt.hist(prices_for_retina, 2, histtype='bar',color='blue')
plt.show()

# %% [markdown]
# # Communicating with APIs

# %%
import requests

response = requests.get("https://www.googleapis.com/books/v1/volumes", params={"q":"machine learning"})
raw_data = response.json()
titles = [item['volumeInfo']['title'] for item in raw_data['items']]
titles
# Out:
# ['The Computational Complexity of Machine Learning',
#  'Elements of Machine Learning',
#  'Machine Learning',
#  'Machine Learning',
#  'Principles and Theory for Data Mining and Machine Learning',
#  'Machine Learning in Non-stationary Environments',
#  'Machine Learning Proceedings 1991',
#  'Machine Learning',
#  'Machine Learning and Image Interpretation',
#  'Graphical Models for Machine Learning and Digital Communication']

# %% [markdown]
# ***
# #### Apis - [reddit comments on apis](https://www.reddit.com/r/webdev/comments/3wrswc/what_are_some_fun_apis_to_play_with/)
# * Riot Games
# * [import.io](https://www.import.io/) - turns HTML pages to JSON
# * Spotify
# * Telegram
# * SoundCloud
# * Reddit
# * YouTube
# * Wunderground - Weather
# * Kandy - Massaging and video calling
# * Star Wars - All aboard the hype train
# * Marvel Comics
# * Mashape - API Market
# * [FoaaS](http://www.foaas.com/) - Fuck off as a Service
# * BreweryDB - Beer, beer, beer
# * Slack
# * Geo Names - Names of places
# * Common Crawl - Lots of data, petabytes of it
# * Programmers API - TV Show Info
# * FitBit - FitBit fitness tracker
# * JawBone - Jawbone fitness tracker
# * Moneypot - BitCoin Gambling
# * Steam - PCMR incoming
# * Twilio - VoiP & Text Messaging
# * Firebase - Build your own API
# * IBM Watson - Cognitive Computing with IBM
# * Lob - Email Postcards
# * Algolia - Search as a Service
# * Battle.net - Blizzard
# * Free Geo IP - Get geolocation of IP
# * The Counted - officer-involved killings in the US
# * Wolfram Alpha
# * IFTTT
# * USDA National Nutrient Database - United States Department of Agriculture
# * Twitter
# * Nutritionix - Nutrition DB
# * Geode Systems - lotsa data
# * Programmable Web API's - /thread (though keep going, this is fun)
# * Pokémon API
# * Open Weather Map - yet more weather

# %% [markdown]
# #### Download some stock data using the api from [Quandl](https://www.quandl.com/)

# %%
import pandas as pd
import sys
sys.path.append('/usr/local/lib/python3.5/site-packages/quandl/')
import quandl

df = quandl.get('WIKI/GOOGL')

# %%
df.head()
# Out:
#               Open    High     Low   Close      Volume  Ex-Dividend  \
# Date
# 2004-08-19  100.00  104.06   95.96  100.34  44659000.0          0.0
# 2004-08-20  101.01  109.08  100.50  108.31  22834300.0          0.0
# 2004-08-23  110.75  113.48  109.05  109.40  18256100.0          0.0
# 2004-08-24  111.24  111.60  103.57  104.87  15247300.0          0.0
# 2004-08-25  104.96  108.00  103.88  106.00   9188600.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
# Date
# 2004-08-19          1.0     50.000      52.03    47.980      50.170
# 2004-08-20          1.0     50.505      54.54    50.250      54.155
# 2004-08-23          1.0     55.375      56.74    54.525      54.700
# 2004-08-24          1.0     55.620      55.80    51.785      52.435
# 2004-08-25          1.0     52.480      54.00    51.940      53.000
#
#             Adj. Volume
# Date
# 2004-08-19   44659000.0
# 2004-08-20   22834300.0
# 2004-08-23   18256100.0
# 2004-08-24   15247300.0
# 2004-08-25    9188600.0

# %% [markdown]
# ### Taking out "relevant" features, we want to at least make the data as easy as possible without losing information

# %%
# We do not need any of the other columns 
# since these will have the same information only in a nicer format
df = df[['Adj. Open',  'Adj. High',  'Adj. Low',  'Adj. Close', 'Adj. Volume']]

# high - low percentage per day
df['highlow_percentage'] = (df['Adj. High'] - df['Adj. Low']) / df['Adj. Close'] * 100.0

# percentage change per day
df['percentage_change'] = (df['Adj. Close'] - df['Adj. Open']) / df['Adj. Open'] * 100.0

# %%
df = df[['Adj. Close', 'highlow_percentage', 'percentage_change', 'Adj. Volume']]
df.head()
# Out:
#             Adj. Close  highlow_percentage  percentage_change  Adj. Volume
# Date
# 2004-08-19      50.170            8.072553           0.340000   44659000.0
# 2004-08-20      54.155            7.921706           7.227007   22834300.0
# 2004-08-23      54.700            4.049360          -1.218962   18256100.0
# 2004-08-24      52.435            7.657099          -5.726357   15247300.0
# 2004-08-25      53.000            3.886792           0.990854    9188600.0

# %% [markdown]
# # Machine Learning
#
# Subfield of artificial intelligence.
#
# ***Learning from examples and experience***
#
# * AlphaGo competing in the game Go
#
# * Similar approach is used in learning to play Mario [MarIO](https://www.youtube.com/watch?v=qv6UVOQ0F44)
#  * A great video for an introduction on neural networks
#
# ***Why is Machine Learning?***
#
# How would start by identifying a fruit
#
# Difference between orange and an apple
# ```python
# def define_fruit():
#     # lots of code
#
# def detect_colors(image):
#     #lots of code
#
# def analyze_shapes(image):
#     # more code
#
# def guess_texture(image):
#     # code.............
#
# ```
#
# Machine Learning Problems can be seperated into a few large categories:
#
# * ***supervised learning***, which data comes from additional attributes that we can predict. Can be either:
#  * ***classification***, discrete output variables
#  * ***regression***, continuous output variables
# * ***unsupervised learning***, which training data consist of input without any target values.

# %% [markdown]
# ## Supervised Learning
# Features already in place
#
# * Collect training data
# * Train Classifier
# * Make Predictions
#
# We want to classify orange from apple
#
# Weight | Texture | Label
# --- | --- | ---
# 150 | Bumpy | Orange
# 170 | Bumpy | Orange
# 140 | Soft | Apple
# 130 | Soft | Apple
# ... | ... | ...

# %%
# input to the classifier
features = [[140, 'soft'], [130,'soft'], [150,'bumpy'],[170,'bumpy']]

# output for the classifier
labels = ['apple', 'apple','orange','orange']

# We need to change the type of input for the classifier so we rename the features into ints

# 1 = 'soft', 0 = 'bumpy'
features = [[140, 1], [130,1], [150,0],[170,0]]

# 0 = 'apple', 1 = 'orange'
labels = [0,0,1,1]

# %% [markdown]
# ### Now that we have the data let's make something from it

# %%
from sklearn import tree

# doesnt know anything yet
clf = tree.DecisionTreeClassifier()

# %% [markdown]
# Now we will train the data to the classifier with the training data that we have

# %%
clf = clf.fit(features,labels)

# %% [markdown]
# *** Notice that we want to predict something that is not in the training data ***

# %%
clf.predict([[160,0]])
# Out:
# array([1])

# %% [markdown]
# # Classic Machine Learning Problem
#
# ## [Iris flower data set](https://en.wikipedia.org/wiki/Iris_flower_data_set)
#
# Classify the type of flower based on
# * width
# * length
# * petal width
# * petal length
#
# scikit comes with some practices [datasets](http://scikit-learn.org/stable/datasets/)

# %%
from sklearn.datasets import load_iris
iris = load_iris()

print(iris.feature_names)
print(iris.target_names)
print(iris.data[0])
print(iris.target[0])
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# ['setosa' 'versicolor' 'virginica']
# [ 5.1  3.5  1.4  0.2]
# 0

# %% [markdown]
# # Preparing Data
# Examples used to "test" the classifiers accurracy.
#
# will ***NOT*** be part of the training data
#
# Usually a standard is to have ***80% training*** and ***20% testing***. But by no means a goto from the start
#
# ### Testing data

# %%
# dataset is constructed in a great way
# so we can get testing data from each example by taking 0,50,100

test_index = [0,50,100]

# %% [markdown]
# ### Training data

# %%
# built based on c computation and mutation of arrays, i.e. its pretty fast
import numpy as np

# training data
train_target = np.delete(iris.target, test_index)
train_data = np.delete(iris.data, test_index, axis=0)

# testing data
test_target = iris.target[test_index]
test_data = iris.data[test_index]

# %% [markdown]
# ## Training classifier

# %%
clf = tree.DecisionTreeClassifier()
clf.fit(train_data, train_target)

# We expect the classifier to give us [0,1,2] from test_target
print(test_target)

print(clf.predict(test_data))
# Out:
# [0 1 2]
# [0 1 2]

# %% [markdown]
# # DONE! we have now made our first machine learning
#
# ### Classification
# * Naive Bayes
# * Decision trees / Random Forest
# * SVM
# * KNN
# * ... many more!
#
# Recall the features that we have, we need to evaluate them carefully.
#
#
# next we will visualize the decision tree to go into more in depth of what actually happens
#
# Code is taken from scikits homepage on [decision tree visualization](http://scikit-learn.org/stable/modules/tree.html)
#
# ## Visualize the Decision Tree Classifier

# %%
import sys
sys.path.append('/usr/local/lib/python3.5/site-packages/pydot/')

import pydotplus
from sklearn.externals.six import StringIO
from IPython.display import Image  
dot_data = StringIO()  
tree.export_graphviz(clf, out_file=dot_data,  
                         feature_names=iris.feature_names,  
                         class_names=iris.target_names,  
                         filled=True, rounded=True,  
                         special_characters=True)  
graph = pydotplus.graph_from_dot_data(dot_data.getvalue()) 
graph.write_pdf("iris.pdf")
Image(graph.create_png())

# %%
# first testing flower
print(test_data[0], test_target[0])

print(iris.feature_names)
print("targets: ",iris.target_names)
# Out:
# [ 5.1  3.5  1.4  0.2] 0
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# targets:  ['setosa' 'versicolor' 'virginica']

# %%
# second testing flower
print(test_data[1], test_target[0])
# Out:
# [ 7.   3.2  4.7  1.4] 0

# %% [markdown]
# # Parting words!
#
# ### *Choosing good features is one of your most important jobs*
#
# cause the ML-models are dumb....
#
# ### *No free hunch*
#
# * be skeptic and try to find loopholes with the data
# * Models get a score function and can be cross-validated but the is for another time
#
#
# # Hope it was fun everyone! Please give feedback on what can be improved!
